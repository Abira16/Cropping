# %%
# %cd /content/drive/MyDrive/Colab Notebooks/crop/yolov3
# Out:
# /content/drive/MyDrive/Colab Notebooks/crop/yolov3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
net=cv2.dnn_DetectionModel('./YOLOv3-416.weights','./yolov3-416.cfg')
net.setInputSize(416, 416)
net.setInputScale(1.0 / 256)
# Out:
# <dnn_Model 0x7f032ca70360>

# %%
#image_dir = os.path.join(os.getcwd(),'test_images')
#img_name_list = glob.glob(image_dir + os.sep + '*')

# %%
#print(img_name_list)

# %%
img=cv2.imread('/content/drive/MyDrive/Colab Notebooks/img111.jpg')
plt.imshow(img)

# %%
h, w, _ = img.shape

# %%
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  classes, confidences, coordinates = net.detect(img, confThreshold=0.3,
                                                 nmsThreshold=0.4)

# %%
print(coordinates)

# %%
  img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
  orig = img.copy()
  cv2.rectangle(orig, coordinates[0], (255, 0, 0), 2)

# %%
plt.imshow(orig)

cv2.imwrite('./img111__22_seg.jpg',orig)
# Out:
# True

# %%
padding =10
if len(coordinates) == 2:
    [x, y, nw, nh] = coordinates[0]
    #print(y, x, nw, nh)
    #print(nh + 4 * padding,h,nw + 2 * padding,w)
    image = img[y:y + nh, x:x + nw]
    plt.imshow(image)
    if (nh + 4 * padding < h):
      nh = nh - 5 * padding
    else:
      nh = h
    if ((nw + 2 * padding) < w):
      nw = nw - 3 * padding
    else:
      nw = w
    if (x - padding > 0):
      x1 = x + 2* padding
      print("x",x)
    else:
      x = 0
    if ((y - padding) > 0):
      y1 = y + 7* padding
    else:
      y = 0
   # print(x, y, nw, nh,y + 6* padding,x-padding)
    image = img[y1:y + nh, x1:x + nw]
    cv2.imwrite('./img111_22_crop.jpg',image)
    #plt.imshow(image)
# Out:
# x 15

# %%
image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.imwrite('./img11_1crop.jpg',image)
plt.imshow(image)
