# %%
# %cd /content/drive/MyDrive/Colab Notebooks/crop/u2
# Out:
# /content/drive/MyDrive/Colab Notebooks/crop/u2

# %%
# %cd u2_net
# Out:
# /content/drive/MyDrive/Colab Notebooks/crop/u2/u2_net

# %%
# !python u2net_test.py
